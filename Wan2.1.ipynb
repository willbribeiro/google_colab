# %%
# #@title Environment Setup

from pathlib import Path

OPTIONS = {}
UPDATE_COMFY_UI = True  #@param {type:"boolean"}
USE_COMFY_UI_MANAGER = True  #@param {type:"boolean"}
INSTALL_CUSTOM_NODES_DEPENDENCIES = True  #@param {type:"boolean"}

# Populate OPTIONS after variables are defined
OPTIONS['UPDATE_COMFY_UI'] = UPDATE_COMFY_UI
OPTIONS['USE_COMFYUI_MANAGER'] = USE_COMFY_UI_MANAGER
OPTIONS['INSTALL_CUSTOM_NODES_DEPENDENCIES'] = INSTALL_CUSTOM_NODES_DEPENDENCIES

# !echo -= Initial setup ConfyUI =-
# !git clone https://github.com/comfyanonymous/ComfyUI.git

if OPTIONS['UPDATE_COMFY_UI']:
  # !echo -= Updating ConfyUI =-
  # %cd /content/ComfyUI
  # !git pull

# !echo -= Install dependencies =-
# !pip3 install accelerate
# !pip3 install einops transformers safetensors aiohttp pyyaml Pillow scipy tqdm psutil tokenizers
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# !pip3 install torchsde
# !pip install Kornia spandrel soundfile sentencepiece

if OPTIONS['USE_COMFYUI_MANAGER']:
  # %cd /content/ComfyUI/custom_nodes
  # !echo -= Initial setup ComfyUI-Manager =-
  # !git clone https://github.com/Comfy-Org/ComfyUI-Manager.git
  # %cd /content/ComfyUI/custom_nodes/ComfyUI-Manager
  # !git pull
  # %cd /content/ComfyUI/

if OPTIONS['INSTALL_CUSTOM_NODES_DEPENDENCIES']:
  # !echo -= Install custom nodes dependencies =-
  # !pip install GitPython
  # !python /content/ComfyUI/custom_nodes/ComfyUI-Manager/cm-cli.py restore-dependencies
# Out:
# -= Initial setup ConfyUI =-
# Cloning into 'ComfyUI'...
# remote: Enumerating objects: 26686, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 26686 (delta 13), reused 2 (delta 2), pack-reused 26665 (from 2)
# Receiving objects: 100% (26686/26686), 74.23 MiB | 15.93 MiB/s, done.
# Resolving deltas: 100% (18003/18003), done.
# -= Updating ConfyUI =-
# /content/ComfyUI
# Already up to date.
# -= Install dependencies =-
# ...
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 15.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 305.2/305.2 kB 29.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 81.2 MB/s eta 0:00:00
# ...
# /content/ComfyUI/custom_nodes
# -= Initial setup ComfyUI-Manager =-
# Cloning into 'ComfyUI-Manager'...
# ...

# %% [markdown]
# # Modelos - Wan 2.1

# %%
#Wan 2.1 Models
# !wget -c https://huggingface.co/Comfy-Org/Wan_2.1_ComfyUI_repackaged/resolve/main/split_files/vae/wan_2.1_vae.safetensors -P /content/ComfyUI/models/vae/
# !wget -c https://huggingface.co/Comfy-Org/Wan_2.1_ComfyUI_repackaged/resolve/main/split_files/text_encoders/umt5_xxl_fp16.safetensors -P /content/ComfyUI/models/text_encoders
# !wget -c https://huggingface.co/Comfy-Org/Wan_2.1_ComfyUI_repackaged/resolve/main/split_files/text_encoders/umt5_xxl_fp8_e4m3fn_scaled.safetensors -P /content/ComfyUI/models/text_encoders
# !wget -c https://huggingface.co/Comfy-Org/Wan_2.1_ComfyUI_repackaged/resolve/main/split_files/clip_vision/clip_vision_h.safetensors -P /content/ComfyUI/models/clip_vision
# !wget -c https://huggingface.co/Comfy-Org/Wan_2.1_ComfyUI_repackaged/resolve/main/split_files/diffusion_models/wan2.1_t2v_1.3B_bf16.safetensors -P /content/ComfyUI/models/diffusion_models
# !wget -c https://huggingface.co/Wan-AI/Wan2.1-T2V-14B/resolve/main/diffusion_pytorch_model-00006-of-00006.safetensors -P /content/ComfyUI/models/diffusion_models
# !wget -c https://huggingface.co/e-n-v-y/Wan2.1_i2v_720p_nf4/resolve/main/Wan2.1_t2v_14B_nf4.safetensors -P /content/ComfyUI/models/diffusion_models
# !wget -c https://huggingface.co/city96/Wan2.1-I2V-14B-480P-gguf/resolve/main/wan2.1-i2v-14b-480p-Q3_K_M.gguf -P /content/ComfyUI/models/unet
# Out:
# --2025-11-14 23:24:23--  https://huggingface.co/Comfy-Org/Wan_2.1_ComfyUI_repackaged/resolve/main/split_files/vae/wan_2.1_vae.safetensors
# Resolving huggingface.co (huggingface.co)... 3.166.152.110, 3.166.152.105, 3.166.152.65, ...
# Connecting to huggingface.co (huggingface.co)|3.166.152.110|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !cd "/content/ComfyUI"

# %% [markdown]
# # Execute o ComfyUI com o Cloudflare (método recomendado)

# %%
# !/usr/bin/python3 -m pip install -r /content/ComfyUI/requirements.txt

# !wget -P ~ https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# !dpkg -i ~/cloudflared-linux-amd64.deb

import subprocess
import threading
import time
import socket
import urllib.request

def iframe_thread(port):
  while True:
      time.sleep(0.5)
      sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
      result = sock.connect_ex(('127.0.0.1', port))
      if result == 0:
        break
      sock.close()
  print("\nComfyUI finished loading, trying to launch cloudflared (if it gets stuck here cloudflared is having issues)\n")

  p = subprocess.Popen(["cloudflared", "tunnel", "--url", "http://127.0.0.1:{}".format(port)], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
  for line in p.stderr:
    l = line.decode()
    if "trycloudflare.com " in l:
      print("This is the URL to access ComfyUI:", l[l.find("http"):], end='')
    #print(l, end='')


threading.Thread(target=iframe_thread, daemon=True, args=(8188,)).start()

# !python /content/ComfyUI/main.py --dont-print-server
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 kB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 MB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 120.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 MB 20.4 MB/s eta 0:00:00
# ...
# --2025-11-14 23:29:43--  https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/cloudflare/cloudflared/releases/download/2025.11.1/cloudflared-linux-amd64.deb [following]
# --2025-11-14 23:29:43--  https://github.com/cloudflare/cloudflared/releases/download/2025.11.1/cloudflared-linux-amd64.deb
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# ...
